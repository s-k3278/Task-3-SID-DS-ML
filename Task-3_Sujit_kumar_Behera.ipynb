# %% [markdown]
# # <center>**SPECTRUM INTENSHIP DRIVE 2021.**</center>
#
# ## <center>**Welcome to the Final task of DS/ML internship of SID 2021.**</center>

# %% [markdown]
# ### <center>In the final task we will be learning about various machine learning pipelines starting from fetching data , preprocessing them , feature selection to building models using **3 REGRESSION algorithms (LINEAR REGRESSION, DECISION TREE REGRESSION, RANDOM FOREST REGRESSION)** and comparing their R Squared score and **3 CLASSIFICATION machine learning algorithms (LOGISTIC REGRESSION, DECISION TREE CLASSIFICATION, RANDOM FOREST CLASSIFICATION)** and comparing their accuracy.

# %% [markdown]
# ![Screenshot (176).png](data:image/png;base64,...)

# %% [markdown]
# #### **Perform the following on the dataset:**
# (not necessarily in the same sequence)
#
# - Exploratory data analysis
#
# - Handle the missing values.
#
# - Make a new column called SalePriceClass,  based on the following conditions.
#
#   - if SalePrice greater than or equal 400000 then SalePriceClass = 'A'
#   - if SalePrice between 300000 and 399999 then SalePriceClass = 'B'
#   - if SalePrice between 200000 and 299999 then SalePriceClass = 'C'
#   - if SalePrice between 100000 and 199999 then SalePriceClass = 'D'
#   - if SalePrice less than or equal 100000 then SalePriceClass = 'E'
#
# - Label Encoding
#
# - Feature Selection
#
# - Outlier detection  and removal.
#
# - Data Scaling
#
# - Spliting the data into train and test set.
#
# - Make use of 3 REGRESSION machine learning algorithms (LINEAR REGRESSION ,DECISION TREE REGRESSION, RANDOM FOREST REGRESSION) and compare their R Squared score.(**Target variable - SalePrice**)
#
# - Make use of 3 CLASSIFICATION machine learning algorithms (LOGISTIC REGRESSION ,DECISION TREE CLASSIFICATION, RANDOM FOREST CLASSIFICATION) and compare their accuracy.(**Target variable - SalePriceClass**)
#
# - Try to optimize hyperparameters using RandomizedSearchCV or GridSearchCV.
#
# - Find the best algorithm for Regression and Classification on the given dataset.
#
# **NOTE-Make sure to make use of markdowns and comments.**

# %% [markdown]
# #### **Resources**
#
# Watching:
# - [The 7 steps of machine learning](https://www.youtube.com/watch?v=nKW8Ndu7Mjw)
# - [How to Build a Machine Learning Model](https://www.youtube.com/watch?v=NRnaMCNOK7Y)
# - [StatQuest: Fitting a line to data, aka least squares, aka linear regression.](https://www.youtube.com/watch?v=PaFPbb66DxQ&list=PLblh5JKOoLUIzaEkCLIUxQFjPIlapw8nU&index=1)
# - [Linear Regression](https://youtu.be/E5RjzSK0fvY)
# - [Logistic Regression](https://www.youtube.com/watch?v=XnOAdxOWXWg)
# - [Decision Tree](https://youtu.be/qDcl-FRnwSU)
# - [Random Forest](https://youtu.be/ok2s1vV9XW0)
# - [Regression Trees, Clearly Explained!!!](https://www.youtube.com/watch?v=g9c66TUylZ4&list=PLblh5JKOoLUKAtDViTvRGFpphEc24M-QH&index=3)
#
# Reading:
#
# - [Data Preprocessing from hackernoon](https://hackernoon.com/what-steps-should-one-take-while-doing-data-preprocessing-502c993e1caa)
# - [Data PreProcessing from datadriveninvestor](https://medium.datadriveninvestor.com/data-science-data-preprocessing-eda-6be2860fbb5d)
# - [The 7 Steps of Machine Learning from towardsdatascience](https://towardsdatascience.com/the-7-steps-of-machine-learning-2877d7e5548e)
# - [The Ultimate Guide to Linear Regression for Machine Learning](https://www.keboola.com/blog/linear-regression-machine-learning)
# - [Decision Trees and Random Forests](https://towardsdatascience.com/decision-trees-and-random-forests-df0c3123f991)
# - [Decision Trees and Random Forests — Explained](https://towardsdatascience.com/decision-tree-and-random-forest-explained-8d20ddabc9dd)
# - [Evaluation Metrics for Regression Model](https://www.analyticsvidhya.com/blog/2021/05/know-the-best-evaluation-metrics-for-your-regression-model/)
# - [Hyperparameter tuning with GridSearchCV and RandomizedSearchCV](https://towardsdatascience.com/machine-learning-gridsearchcv-randomizedsearchcv-d36b89231b10)
# - [Random Search to Optimize Hyperparameters](https://www.section.io/engineering-education/random-search-hyperparameters/)

# %% [markdown]
# ### NOTE-The below layout is made just for convenience. Add or delete cells and sub-sections according to your own requirement

# %% [markdown]
# # Loading Data

# %%
# Run this cell to download the dataset required for this task
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1WoXkw5WKJnquoTqh25B70qFkVO-vaQgp' -O 'final_task.csv'
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'id' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Understanding and handling data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from scipy import stats

# %%
df = pd.read_csv('housing_prices.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
#df['SalePriceClass'] = np.NAN
#for i,j in df.iterrows():
#  if df.SalePrice[i] > 400000:
#    df.SalePriceClass[i] = 'A'
#  elif df.SalePrice[i] > 300000:
#    df.SalePriceClass[i] = 'B'
#  elif df.SalePrice[i] > 200000:
#    df.SalePriceClass[i] = 'C'
#  elif df.SalePrice[i] > 100000:
#    df.SalePriceClass[i] = 'D'
#  else:
#    df.SalePriceClass[i] = 'E'

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 81

# %% [markdown]
# # EDA

# %% [markdown]
# ## 1 - Mean SalePrice in each Neighborhood

# %%
fig, ax = plt.subplots(figsize=(15,6))
df.groupby('Neighborhood')['SalePrice'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %% [markdown]
# ## 2 - Frequency of House in Neighborhoods

# %%
fig, ax = plt.subplots(figsize=(15,6))
df['Neighborhood'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3 - Mean Sale Price by HouseStyle

# %%
fig, ax = plt.subplots(figsize=(15,6))
df.groupby('HouseStyle')['SalePrice'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='HouseStyle'>

# %% [markdown]
# ## 4 - Frequency of HouseStyle

# %%
fig, ax = plt.subplots(figsize=(15,6))
df['HouseStyle'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5 - No of Houses based on YearBuilt

# %%
fig, ax = plt.subplots(figsize=(20,6))
df['YearBuilt'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 6 - Yearbuilt and SalePrice Plot

# %%
sns.jointplot(data=df, x="YearBuilt", y="SalePrice", kind="kde", height=8.27, aspect=11.7/8.27)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:1181: UserWarning: The following kwargs were not used by contour: 'aspect'
#   cset = contour_func(

# %% [markdown]
# ## 7 - HouseStyle and SalePrice Plot

# %%
sns.jointplot(data=df, x="YearBuilt", y="SalePrice",hue="HouseStyle", kind="scatter")

# %% [markdown]
# # Conclusions :-
# ##    1 - We see that house prices are higher in NoRidge, Nridght, StoneBr than other places.
# ##    2 - Names has more houses for Sale than most other neighborhoods.
# ##    3 - Prices of 2.5Fin and 2Story are higher.
# ##    4 - Most houses for sale are 1 story.
# ##    5 - Houses built in 2005 are heighest priced
# ##    6 - Houses Built in between 1990 & 2005 are higher priced.

# %% [markdown]
# # Feature Engineering

# %%
df['SalePriceClass'] = np.NAN
for i,j in df.iterrows():
  if df.SalePrice[i] > 400000:
    df.SalePriceClass[i] = 'A'
  elif df.SalePrice[i] > 300000:
    df.SalePriceClass[i] = 'B'
  elif df.SalePrice[i] > 200000:
    df.SalePriceClass[i] = 'C'
  elif df.SalePrice[i] > 100000:
    df.SalePriceClass[i] = 'D'
  else:
    df.SalePriceClass[i] = 'E'
# Out:
# <ipython-input-20-82a597d84963>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.SalePriceClass[i] = 'C'
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-20-82a597d84963>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.SalePriceClass[i] = 'D'
# <ipython-input-20-82a597d84963>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.SalePriceClass[i] = 'B'
# <ipython-input-20-82a597d84963>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.SalePriceClass[i] = 'E'
# <ipython-input-20-82a597d84963>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.SalePriceClass[i] = 'A'

# %% [markdown]
# # Feature Selection

# %%
null_df = pd.DataFrame(df.isna().sum())
null_df[null_df[0] != 0]
# Out:
#                  0
# LotFrontage    259
# Alley         1369
# MasVnrType       8
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# FireplaceQu    690
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# PoolQC        1453
# Fence         1179
# MiscFeature   1406

# %% [markdown]
# We see a lot of null values in some columns that can be droped

# %%
df = df.drop('PoolQC',axis=1)
df = df.drop('Fence',axis=1)
df = df.drop('MiscFeature',axis=1)
df = df.drop('Alley',axis=1)
df = df.drop('FireplaceQu',axis=1)
df = df.drop('LotFrontage',axis=1)

# %%
null_df = pd.DataFrame(df.isna().sum())
null_df[null_df[0] != 0]
# Out:
#                0
# MasVnrType     8
# MasVnrArea     8
# BsmtQual      37
# BsmtCond      37
# BsmtExposure  38
# BsmtFinType1  37
# BsmtFinType2  38
# Electrical     1
# GarageType    81
# GarageYrBlt   81
# GarageFinish  81
# GarageQual    81
# GarageCond    81

# %% [markdown]
# Lets Drop the rest of the Null Values

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              1338 non-null   int64
#  1   MSSubClass      1338 non-null   int64
#  2   MSZoning        1338 non-null   object
#  3   LotArea         1338 non-null   int64
#  4   Street          1338 non-null   object
#  5   LotShape        1338 non-null   object
#  6   LandContour     1338 non-null   object
#  7   Utilities       1338 non-null   object
#  8   LotConfig       1338 non-null   object
#  9   LandSlope       1338 non-null   object
#  10  Neighborhood    1338 non-null   object
#  11  Condition1      1338 non-null   object
#  12  Condition2      1338 non-null   object
#  13  BldgType        1338 non-null   object
#  14  HouseStyle      1338 non-null   object
#  15  OverallQual     1338 non-null   int64
#  16  OverallCond     1338 non-null   int64
#  17  YearBuilt       1338 non-null   int64
#  18  YearRemodAdd    1338 non-null   int64
#  19  RoofStyle       1338 non-null   object
#  20  RoofMatl        1338 non-null   object
#  21  Exterior1st     1338 non-null   object
#  22  Exterior2nd     1338 non-null   object
#  23  MasVnrType      1338 non-null   object
#  24  MasVnrArea      1338 non-null   float64
#  25  ExterQual       1338 non-null   object
#  26  ExterCond       1338 non-null   object
#  27  Foundation      1338 non-null   object
#  28  BsmtQual        1338 non-null   object
#  29  BsmtCond        1338 non-null   object
#  30  BsmtExposure    1338 non-null   object
#  31  BsmtFinType1    1338 non-null   object
#  32  BsmtFinSF1      1338 non-null   int64
#  33  BsmtFinType2    1338 non-null   object
#  34  BsmtFinSF2      1338 non-null   int64
#  35  BsmtUnfSF       1338 non-null   int64
#  36  TotalBsmtSF     1338 non-null   int64
#  37  Heating         1338 non-null   object
#  38  HeatingQC       1338 non-null   object
#  39  CentralAir      1338 non-null   object
#  40  Electrical      1338 non-null   object
#  41  1stFlrSF        1338 non-null   int64
#  42  2ndFlrSF        1338 non-null   int64
#  43  LowQualFinSF    1338 non-null   int64
#  44  GrLivArea       1338 non-null   int64
#  45  BsmtFullBath    1338 non-null   int64
#  46  BsmtHalfBath    1338 non-null   int64
#  47  FullBath        1338 non-null   int64
#  48  HalfBath        1338 non-null   int64
#  49  BedroomAbvGr    1338 non-null   int64
#  50  KitchenAbvGr    1338 non-null   int64
#  51  KitchenQual     1338 non-null   object
#  52  TotRmsAbvGrd    1338 non-null   int64
#  53  Functional      1338 non-null   object
#  54  Fireplaces      1338 non-null   int64
#  55  GarageType      1338 non-null   object
#  56  GarageYrBlt     1338 non-null   float64
#  57  GarageFinish    1338 non-null   object
#  58  GarageCars      1338 non-null   int64
#  59  GarageArea      1338 non-null   int64
#  60  GarageQual      1338 non-null   object
#  61  GarageCond      1338 non-null   object
#  62  PavedDrive      1338 non-null   object
#  63  WoodDeckSF      1338 non-null   int64
#  64  OpenPorchSF     1338 non-null   int64
#  65  EnclosedPorch   1338 non-null   int64
#  66  3SsnPorch       1338 non-null   int64
#  67  ScreenPorch     1338 non-null   int64
#  68  PoolArea        1338 non-null   int64
#  69  MiscVal         1338 non-null   int64
#  70  MoSold          1338 non-null   int64
#  71  YrSold          1338 non-null   int64
#  72  SaleType        1338 non-null   object
#  73  SaleCondition   1338 non-null   object
#  74  SalePrice       1338 non-null   int64
#  75  SalePriceClass  1338 non-null   object
# dtypes: float64(2), int64(35), object(39)
# memory usage: 804.9+ KB

# %% [markdown]
# We also saw a lot of object type Features that needs to be Encoded.

# %%
le = LabelEncoder()
for col, value in df.items():
  if(df[col].dtype==np.dtype('O')):
    column = col
    df[col] = le.fit_transform(df[col].astype(str))

# %%
df.corr().abs()
# Out:
#                       Id  MSSubClass  MSZoning   LotArea    Street  LotShape  \
# Id              1.000000    0.016725  0.007394  0.036083  0.006018  0.033823
# MSSubClass      0.016725    1.000000  0.019852  0.134158  0.020591  0.101590
# MSZoning        0.007394    0.019852  1.000000  0.026123  0.100472  0.057472
# LotArea         0.036083    0.134158  0.026123  1.000000  0.215095  0.162595
# Street          0.006018    0.020591  0.100472  0.215095  1.000000  0.004162
# ...                  ...         ...       ...       ...       ...       ...
# YrSold          0.002241    0.021591  0.023209  0.012066  0.036572  0.031659
# SaleType        0.014868    0.011012  0.092456  0.014410  0.019380  0.007836
# SaleCondition   0.000839    0.011692  0.003117  0.031465  0.011846  0.032899
# SalePrice       0.030473    0.079599  0.163809  0.254757  0.042106  0.253092
# SalePriceClass  0.047610    0.111534  0.148143  0.237582  0.045391  0.221171
#
#                 LandContour  Utilities  LotConfig  LandSlope  ...  3SsnPorch  \
# Id                 0.015138   0.013866   0.062311   0.005724  ...   0.043766
# MSSubClass         0.004685   0.023965   0.063066   0.012477  ...   0.041391
# MSZoning           0.024760   0.001048   0.020602   0.021658  ...   0.001516
# LotArea            0.169102   0.009710   0.120209   0.458152  ...   0.019326
# Street             0.141519   0.001675   0.022597   0.206116  ...   0.007269
# ...                     ...        ...        ...        ...  ...        ...
# YrSold             0.018654   0.024555   0.007448   0.000975  ...   0.023326
# SaleType           0.027535   0.129813   0.007544   0.055246  ...   0.009785
# SaleCondition      0.005750   0.098211   0.059447   0.059367  ...   0.000002
# SalePrice          0.001517   0.017079   0.065735   0.061629  ...   0.042159
# SalePriceClass     0.000611   0.013128   0.059691   0.051700  ...   0.034577
#
#                 ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SaleType  \
# Id                 0.000904  0.059455  0.002206  0.020939  0.002241  0.014868
# MSSubClass         0.022748  0.010199  0.021512  0.016283  0.021591  0.011012
# MSZoning           0.022453  0.002750  0.002839  0.011369  0.023209  0.092456
# LotArea            0.038489  0.077050  0.040824  0.000118  0.012066  0.014410
# Street             0.038169  0.004396  0.026514  0.001547  0.036572  0.019380
# ...                     ...       ...       ...       ...       ...       ...
# YrSold             0.013332  0.061701  0.002566  0.144862  1.000000  0.005334
# SaleType           0.006998  0.011886  0.014457  0.038388  0.005334  1.000000
# SaleCondition      0.031065  0.075309  0.009747  0.026561  0.006214  0.202453
# SalePrice          0.096624  0.091881  0.016990  0.041310  0.020451  0.045856
# SalePriceClass     0.071128  0.045425  0.027966  0.041847  0.023028  0.050635
#
#                 SaleCondition  SalePrice  SalePriceClass
# Id                   0.000839   0.030473        0.047610
# MSSubClass           0.011692   0.079599        0.111534
# MSZoning             0.003117   0.163809        0.148143
# LotArea              0.031465   0.254757        0.237582
# Street               0.011846   0.042106        0.045391
# ...                       ...        ...             ...
# YrSold               0.006214   0.020451        0.023028
# SaleType             0.202453   0.045856        0.050635
# SaleCondition        1.000000   0.202301        0.203485
# SalePrice            0.202301   1.000000        0.921686
# SalePriceClass       0.203485   0.921686        1.000000
#
# [76 rows x 76 columns]

# %% [markdown]
# We see a lot of low corelation features that can be removed.

# %%
corr_matrix = df.corr().abs()

# %%
sp_corr = corr_matrix['SalePrice']

# %%
sp_corr
# Out:
# Id                0.030473
# MSSubClass        0.079599
# MSZoning          0.163809
# LotArea           0.254757
# Street            0.042106
#                     ...
# YrSold            0.020451
# SaleType          0.045856
# SaleCondition     0.202301
# SalePrice         1.000000
# SalePriceClass    0.921686
# Name: SalePrice, Length: 76, dtype: float64

# %%
to_drop=[]
for i in range(len(sp_corr)):
  if sp_corr[i] < 0.3:
    to_drop.append(i)
df = df.drop(df.columns[to_drop],axis=1)

# %%
fig, ax = plt.subplots(ncols=5,nrows=6, figsize = (22,20))
index = 0
ax = ax.flatten()

for col, value in df.items():
  sns.boxplot(y=col, data=df, ax=ax[index])
  index+=1

# %% [markdown]
# We see some columns have some outliers but we expect to treat them

# %%
df.boxplot('GarageArea')
# Out:
# <AxesSubplot:>

# %%
df = df[df.GarageArea <1000]

# %%
df.boxplot('GrLivArea')
# Out:
# <AxesSubplot:>

# %%
df=df[df.GrLivArea<3000]

# %%
df.boxplot('TotalBsmtSF')
# Out:
# <AxesSubplot:>

# %%
df=df[df.TotalBsmtSF<2000]

# %% [markdown]
# Checking Shape to see the new DF Dimensions after droping rows and columns.

# %%
df.shape
# Out:
# (1291, 26)

# %% [markdown]
# DATA SCALING

# %% [markdown]
# ## Checking Histograms For Skewed Data

# %%
df.hist(figsize=(22,20))
# Out:
# array([[<AxesSubplot:title={'center':'OverallQual'}>,
#         <AxesSubplot:title={'center':'YearBuilt'}>,
#         <AxesSubplot:title={'center':'YearRemodAdd'}>,
#         <AxesSubplot:title={'center':'MasVnrArea'}>,
#         <AxesSubplot:title={'center':'ExterQual'}>],
#        [<AxesSubplot:title={'center':'Foundation'}>,
#         <AxesSubplot:title={'center':'BsmtQual'}>,
#         <AxesSubplot:title={'center':'BsmtFinSF1'}>,
#         <AxesSubplot:title={'center':'TotalBsmtSF'}>,
#         <AxesSubplot:title={'center':'HeatingQC'}>],
#        [<AxesSubplot:title={'center':'1stFlrSF'}>,
#         <AxesSubplot:title={'center':'2ndFlrSF'}>,
#         <AxesSubplot:title={'center':'GrLivArea'}>,
#         <AxesSubplot:title={'center':'FullBath'}>,
#         <AxesSubplot:title={'center':'KitchenQual'}>],
#        [<AxesSubplot:title={'center':'TotRmsAbvGrd'}>,
#         <AxesSubplot:title={'center':'Fireplaces'}>,
#         <AxesSubplot:title={'center':'GarageType'}>,
#         <AxesSubplot:title={'center':'GarageYrBlt'}>,
#         <AxesSubplot:title={'center':'GarageFinish'}>],
#        [<AxesSubplot:title={'center':'GarageCars'}>,
#         <AxesSubplot:title={'center':'GarageArea'}>,
#         <AxesSubplot:title={'center':'WoodDeckSF'}>,
#         <AxesSubplot:title={'center':'OpenPorchSF'}>,
#         <AxesSubplot:title={'center':'SalePrice'}>],
#        [<AxesSubplot:title={'center':'SalePriceClass'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
for i in df.columns:
  if abs(df[i].skew())>0.5:
    print(i,df[i].skew())
# Out:
# YearBuilt -0.6486791868424744
# YearRemodAdd -0.5382684533681956
# MasVnrArea 2.5159998665744374
# ExterQual -1.7424478915277075
# BsmtQual -1.3248563708313121
# BsmtFinSF1 0.6030293200858708
# 1stFlrSF 0.6051474613362104
# 2ndFlrSF 0.6799187113300081
# GrLivArea 0.616584897816815
# KitchenQual -1.4613852403991585
# TotRmsAbvGrd 0.5898022276673524
# Fireplaces 0.5837166906958605
# GarageType 0.7677332718493073
# GarageYrBlt -0.6434696475202484
# WoodDeckSF 1.5424370903800733
# OpenPorchSF 2.2608769220892135
# SalePrice 1.2185186504010768
# SalePriceClass -1.0756634089590342

# %% [markdown]
# We see most of them are more than 1 and we need to transform them.

# %% [markdown]
# We need to apply log transform to SalePrice as it is highly skewed.

# %%
sns.histplot(df['SalePrice'],kde=True)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
df['SalePrice'].skew()
# Out:
# 1.2185186504010768

# %%
sns.histplot(np.log10(df['SalePrice']),kde=True)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
np.log10(df['SalePrice']).skew()
# Out:
# 0.05765445952183321

# %%
df['SalePrice'] = np.log(df['SalePrice'])

# %%
print(df['ExterQual'].skew())
print(np.power(df['ExterQual'],3).skew())
df['ExterQual'] = np.power(df['ExterQual'],3)
# Out:
# -1.7424478915277075
# -0.5426462361775484

# %%
print(df['BsmtQual'].skew())
print(np.power(df['BsmtQual'],3).skew())
df['BsmtQual'] = np.power(df['BsmtQual'],3)
# Out:
# -1.3248563708313121
# 0.034047223273505046

# %%
print(df['KitchenQual'].skew())
print(np.power(df['KitchenQual'],3).skew())
df['KitchenQual'] = np.power(df['KitchenQual'],3)
# Out:
# -1.4613852403991585
# -0.12066680775822718

# %%
x = df.drop('SalePrice',axis= 1)

# %%
y = df['SalePrice']

# %%
score_dict = {'Model Name':['Best Score','Test Score']}

# %% [markdown]
# # Model Building

# %% [markdown]
# #### REGRESSION

# %% [markdown]
# 1)LINEAR REGRESSION

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)
lr = LinearRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)
score=r2_score(y_test,y_pred)

# %%
score_dict['Linear Regression'] = ['-',score]

# %% [markdown]
# 2)Decision Tree Regressor

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
grid_param = {'min_samples_split': range(1,100,10), 'min_samples_leaf': range(1,100,10)}

# %%
gd_sr = GridSearchCV(estimator = DecisionTreeRegressor(),param_grid=grid_param,scoring='r2',cv=5,n_jobs=-1)

# %%
gd_sr.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'min_samples_leaf': range(1, 100, 10),
#                          'min_samples_split': range(1, 100, 10)},
#              scoring='r2')

# %%
best_parameters = gd_sr.best_params_
print(best_parameters)
# Out:
# {'min_samples_leaf': 11, 'min_samples_split': 61}

# %%
best_result = gd_sr.best_score_
print(best_result)
# Out:
# 0.8794516343323107

# %%
dtr = DecisionTreeRegressor(min_samples_split = best_parameters['min_samples_split'], min_samples_leaf = best_parameters['min_samples_leaf'])
dtr.fit(x_train,y_train)
y_pred = dtr.predict(x_test)
score=r2_score(y_test,y_pred)

# %%
score_dict['Decision Tree Regressor'] = [best_result,score]

# %% [markdown]
# # RandomForestRegression

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
grid_param = {'n_estimators': range(100,1000,100)}

# %%
gd_sr = GridSearchCV(estimator=RandomForestRegressor(),param_grid=grid_param,scoring='r2',cv=5,n_jobs=-1)

# %%
gd_sr.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'n_estimators': range(100, 1000, 100)}, scoring='r2')

# %%
best_parameters = gd_sr.best_params_
print(best_parameters)
# Out:
# {'n_estimators': 400}

# %%
best_result = gd_sr.best_score_
print(best_result)
# Out:
# 0.9175338422675271

# %%
rfc = RandomForestRegressor(n_estimators=best_parameters['n_estimators'])
rfc.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=400)

# %%
y_pred = rfc.predict(x_test)

# %%
score=r2_score(y_test,y_pred)

# %%
score_dict['RandomForestRegression'] = [best_result,score]

# %% [markdown]
# #### CLASSIFICATION

# %% [markdown]
# 1)Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression(random_state=0)
# x remains same
y = df['SalePriceClass']
logisticRegr.fit(x,y)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)
